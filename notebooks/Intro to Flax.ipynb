# %% [markdown]
# # `Flax`
#
# You may have heard of `TensorFlow`, one of the first hugely popular libraries for computing data flow graphs -- operations which we've effectively been doing much of this class, and are the underpinning of neural networks.  `Flax` is effectively `TensorFlow` built on `JAX`, and will be our main library for constructing and training neural networks.

# %%
import jax
from jax import random, numpy as jnp
from flax import linen as nn

from numpy import genfromtxt
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear Regression as a Neural Network
#
# We'll repeat (again) our linear regression example, but this time using `Flax` perform linear regression using a single dense neural network layer.
#
# First let's read in the data.

# %%
data = genfromtxt('../data/data_yerr.dat', names=True, comments='#', delimiter='&')

train_X = jnp.array(data['x'])
train_Y = jnp.array(data['y'])

n_samples = train_X.shape[0]
plt.scatter(train_X, train_Y)
plt.xlabel('$x$')
plt.ylabel('$y$');

# %% [markdown]
# Let's reshape:

# %%
X = data['x'].reshape(-1, 1)
y = data['y'].reshape(-1, 1)
X_tst = jnp.linspace(X.min(), X.max(), 100).reshape(-1, 1)

# %% [markdown]
# To replicate linear regression we just need a single dense layer with a single output.  We'll use the `flax.nn` module to define our model.

# %%
# We create one dense layer instance, where 'features' sets the output dimension
model = nn.Dense(features=1)

# %% [markdown]
# The models don't actually store the parameters, so we need to initialize them with the `init` method.  We'll use the `jax.random.PRNGKey` to seed the random number generator as we have before.

# %%
key1, key2 = random.split(random.PRNGKey(0)) # random keys
params = model.init(key2, X[0])       # provide an example input so it can infer the shapes
params
# Out:
# {'params': {'kernel': Array([[-0.32806483]], dtype=float32),
#   'bias': Array([0.], dtype=float32)}}

# %% [markdown]
# We can see that `params` has a kernel (i.e., weights, or slope in this case) and bias (y-intercept), initialized to random and zero values, respectively.

# %% [markdown]
# If we want to compute a forward pass of our model (i.e., plug in a `x` value and get a predicted `y` value), we can use the `apply` method.  Remember the parameters (slope and y-intercept) aren't stored in the model, so we need to provide them.

# %%
model.apply(params, X[0]) # example application of the model
# Out:
# Array([-65.94103], dtype=float32)

# %% [markdown]
# ## Cost Function
#
# Recall that performing linear regression is equivalent to minimizing the mean squared error (MSE) between the model predictions and the data.
#
# We're going to minimize the MSE using gradient descent, and we'll write everything from scratch as an excuse to learn how to use `Flax`.
#
# First the cost function.  We're going to have `JAX` do some optimization with just-in-time (JIT) compiling (see [here](https://jax.readthedocs.io/en/latest/notebooks/quickstart.html#using-jit-to-speed-up-functions) for gorier details).

# %%
@jax.jit
def mse(params, X, Y):
    # the squared loss for a single (x, y) pair
    def squared_error(x, y):
        pred = model.apply(params, x)
        return jnp.inner(y - pred, y - pred)
    # vectorize this to compute the average loss over a batch of data
    return jnp.mean(jax.vmap(squared_error)(X, Y), axis=0)

# %%
mse(params, X, y)
# Out:
# Array(238343.3, dtype=float32)

# %%
# %timeit mse(params, X, y)
# Out:
# 6.82 μs ± 53.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# It works, and it's fast!  Try commenting out the `@jax.jit` decorator and rerun the two cells above to compare run times.
#
# ## Gradient Decent
#
# Recall the algorithm for gradient decent:
# $$
# \mathrm{repeat~until~convergence} \{\\
# \theta_j = \theta_j - \alpha \frac{\partial}{\partial\theta_j}J(\theta_0, \theta_1) \mathrm{~~~~for~}j=0\mathrm{~and~}j=1
# \\\}
# $$
#
# where $\alpha$ is the *learning rate*.
#
# Remember that one of `JAX`'s superpowers is that it can automatically compute gradients of functions.  `jax.value_and_grad()` will give us a function that computes the value and gradient of our MSE cost function for us.

# %%
loss_grad_fn = jax.value_and_grad(mse)
loss_grad_fn(params, X, y)
# Out:
# (Array(238343.3, dtype=float32),
#  {'params': {'bias': Array([-952.50885], dtype=float32),
#    'kernel': Array([[-170706.06]], dtype=float32)}})

# %% [markdown]
# Let's use it to update parameters during gradient decent.

# %%
learning_rate = 0.00001 # Gradient descent step size

@jax.jit
def update_params(params, learning_rate, grads):
    params = jax.tree_util.tree_map(
        lambda p, g: p - learning_rate * g, params, grads)
    return params

# %% [markdown]
# ...and finally put it all together:

# %%
loss_vals = []
for step in range(1000):
    loss_val, grads = loss_grad_fn(params, X, y)
    params = update_params(params, learning_rate, grads)
    if step % 10 == 0: # print every 10 steps
        print(f"Step {step}, loss {loss_val}")
    loss_vals.append(loss_val)
# Out:
# Step 0, loss 238343.296875
# Step 10, loss 17517.904296875
# Step 20, loss 17517.58984375
# Step 30, loss 17517.265625
# Step 40, loss 17516.9453125
# Step 50, loss 17516.626953125
# Step 60, loss 17516.310546875
# Step 70, loss 17515.98828125
# Step 80, loss 17515.666015625
# Step 90, loss 17515.349609375
# Step 100, loss 17515.02734375
# Step 110, loss 17514.70703125
# Step 120, loss 17514.388671875
# Step 130, loss 17514.0703125
# Step 140, loss 17513.75
# Step 150, loss 17513.4296875
# Step 160, loss 17513.111328125
# Step 170, loss 17512.791015625
# Step 180, loss 17512.470703125
# Step 190, loss 17512.1484375
# Step 200, loss 17511.833984375
# Step 210, loss 17511.513671875
# Step 220, loss 17511.19140625
# Step 230, loss 17510.87109375
# Step 240, loss 17510.552734375
# Step 250, loss 17510.232421875
# Step 260, loss 17509.912109375
# Step 270, loss 17509.591796875
# Step 280, loss 17509.265625
# Step 290, loss 17508.95703125
# Step 300, loss 17508.63671875
# Step 310, loss 17508.314453125
# Step 320, loss 17507.994140625
# Step 330, loss 17507.669921875
# Step 340, loss 17507.3515625
# Step 350, loss 17507.033203125
# Step 360, loss 17506.716796875
# Step 370, loss 17506.3984375
# Step 380, loss 17506.078125
# Step 390, loss 17505.755859375
# Step 400, loss 17505.435546875
# Step 410, loss 17505.12109375
# Step 420, loss 17504.802734375
# Step 430, loss 17504.48046875
# Step 440, loss 17504.16015625
# Step 450, loss 17503.83984375
# Step 460, loss 17503.525390625
# Step 470, loss 17503.205078125
# Step 480, loss 17502.88671875
# Step 490, loss 17502.56640625
# Step 500, loss 17502.244140625
# Step 510, loss 17501.927734375
# Step 520, loss 17501.607421875
# Step 530, loss 17501.287109375
# Step 540, loss 17500.966796875
# Step 550, loss 17500.650390625
# Step 560, loss 17500.328125
# Step 570, loss 17500.009765625
# Step 580, loss 17499.689453125
# Step 590, loss 17499.37109375
# Step 600, loss 17499.05078125
# Step 610, loss 17498.732421875
# Step 620, loss 17498.412109375
# Step 630, loss 17498.095703125
# Step 640, loss 17497.7734375
# Step 650, loss 17497.45703125
# Step 660, loss 17497.138671875
# Step 670, loss 17496.822265625
# Step 680, loss 17496.498046875
# Step 690, loss 17496.177734375
# Step 700, loss 17495.857421875
# Step 710, loss 17495.54296875
# Step 720, loss 17495.220703125
# Step 730, loss 17494.900390625
# Step 740, loss 17494.5859375
# Step 750, loss 17494.263671875
# Step 760, loss 17493.943359375
# Step 770, loss 17493.626953125
# Step 780, loss 17493.302734375
# Step 790, loss 17492.990234375
# Step 800, loss 17492.66796875
# Step 810, loss 17492.349609375
# Step 820, loss 17492.03125
# Step 830, loss 17491.71484375
# Step 840, loss 17491.392578125
# Step 850, loss 17491.072265625
# Step 860, loss 17490.755859375
# Step 870, loss 17490.439453125
# Step 880, loss 17490.1171875
# Step 890, loss 17489.80078125
# Step 900, loss 17489.48046875
# Step 910, loss 17489.162109375
# Step 920, loss 17488.841796875
# Step 930, loss 17488.5234375
# Step 940, loss 17488.208984375
# Step 950, loss 17487.8828125
# Step 960, loss 17487.5703125
# Step 970, loss 17487.248046875
# Step 980, loss 17486.927734375
# Step 990, loss 17486.611328125

# %%
plt.plot(loss_vals);

# %%
plt.scatter(X, y)
plt.plot(X_tst, model.apply(params, X_tst));

# %% [markdown]
# ## Fancier Optimization

# %%
import optax
tx = optax.adam(learning_rate=learning_rate)
opt_state = tx.init(params)
loss_grad_fn = jax.value_and_grad(mse)

# %%
for i in range(1001):
  loss_val, grads = loss_grad_fn(params, X, y)
  updates, opt_state = tx.update(grads, opt_state)
  params = optax.apply_updates(params, updates)
  if i % 10 == 0:
    print('Loss step {}: '.format(i), loss_val)
# Out:
# Loss step 0:  17486.295
# Loss step 10:  17486.287
# Loss step 20:  17486.28
# Loss step 30:  17486.275
# Loss step 40:  17486.271
# Loss step 50:  17486.264
# Loss step 60:  17486.256
# Loss step 70:  17486.254
# Loss step 80:  17486.248
# Loss step 90:  17486.242
# Loss step 100:  17486.236
# Loss step 110:  17486.232
# Loss step 120:  17486.225
# Loss step 130:  17486.219
# Loss step 140:  17486.213
# Loss step 150:  17486.209
# Loss step 160:  17486.201
# Loss step 170:  17486.195
# Loss step 180:  17486.191
# Loss step 190:  17486.186
# Loss step 200:  17486.178
# Loss step 210:  17486.174
# Loss step 220:  17486.17
# Loss step 230:  17486.162
# Loss step 240:  17486.158
# Loss step 250:  17486.152
# Loss step 260:  17486.146
# Loss step 270:  17486.139
# Loss step 280:  17486.133
# Loss step 290:  17486.127
# Loss step 300:  17486.121
# Loss step 310:  17486.12
# Loss step 320:  17486.113
# Loss step 330:  17486.11
# Loss step 340:  17486.1
# Loss step 350:  17486.096
# Loss step 360:  17486.088
# Loss step 370:  17486.084
# Loss step 380:  17486.076
# Loss step 390:  17486.068
# Loss step 400:  17486.066
# Loss step 410:  17486.059
# Loss step 420:  17486.055
# Loss step 430:  17486.047
# Loss step 440:  17486.041
# Loss step 450:  17486.04
# Loss step 460:  17486.03
# Loss step 470:  17486.025
# Loss step 480:  17486.021
# Loss step 490:  17486.014
# Loss step 500:  17486.012
# Loss step 510:  17486.006
# Loss step 520:  17485.998
# Loss step 530:  17485.99
# Loss step 540:  17485.988
# Loss step 550:  17485.982
# Loss step 560:  17485.977
# Loss step 570:  17485.97
# Loss step 580:  17485.967
# Loss step 590:  17485.959
# Loss step 600:  17485.955
# Loss step 610:  17485.947
# Loss step 620:  17485.943
# Loss step 630:  17485.936
# Loss step 640:  17485.932
# Loss step 650:  17485.93
# Loss step 660:  17485.92
# Loss step 670:  17485.914
# Loss step 680:  17485.912
# Loss step 690:  17485.904
# Loss step 700:  17485.9
# Loss step 710:  17485.889
# Loss step 720:  17485.88
# Loss step 730:  17485.877
# Loss step 740:  17485.873
# Loss step 750:  17485.867
# Loss step 760:  17485.861
# Loss step 770:  17485.855
# Loss step 780:  17485.85
# Loss step 790:  17485.844
# Loss step 800:  17485.838
# Loss step 810:  17485.834
# Loss step 820:  17485.826
# Loss step 830:  17485.822
# Loss step 840:  17485.818
# Loss step 850:  17485.812
# Loss step 860:  17485.809
# Loss step 870:  17485.799
# Loss step 880:  17485.795
# Loss step 890:  17485.791
# Loss step 900:  17485.785
# Loss step 910:  17485.78
# Loss step 920:  17485.773
# Loss step 930:  17485.768
# Loss step 940:  17485.762
# Loss step 950:  17485.756
# Loss step 960:  17485.75
# Loss step 970:  17485.746
# Loss step 980:  17485.738
# Loss step 990:  17485.732
# Loss step 1000:  17485.727

# %%
plt.scatter(X, y)
plt.plot(X_tst, model.apply(params, X_tst));
